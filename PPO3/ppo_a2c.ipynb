# %% [markdown]
# # PPO and A2C
#
# **Note** : this script is inspired from the 1st assignment (without correction) from the RL course of the MVA master by A. Lazaric and M. Pirotta, on finite MDP and function approximation, which required to complete a partial implementation of A2C for discrete action space. It has been extended to include a different critic and actor architecture, continuous action space, and the clipped and adaptative KL losses required for PPO.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import numpy as np
from pathlib import Path
import seaborn as sns
import matplotlib.pyplot as plt
from pprint import pprint

try :
    import Box2D
except :
    # !pip install Box2D
import pickle as pkl

# from pyvirtualdisplay import Display
# from IPython import display as ipythondisplay
# from IPython.display import clear_output
# import base64
######################## Import internal modules 
# import utils
#device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#print("using GPU" if device.type=="cuda" else "using CPU" )
#print("Device name: ", torch.cuda.get_device_name())
from config import reset_config#, get_arguments
from plots import plot_sumup
from ppo import PPOAgent

# %%
try :
    from google.colab import drive
    drive.mount('/content/drive/')
    # %cd /content/drive/My\ Drive/RL-PPO
except :
    print("Script running locally")
# Out:
# Script running locally

# %% [markdown]
# ## Setup the environment
# See https://github.com/openai/gym/wiki/Leaderboard for description of OpenAIGym environments

# %% [markdown]
# Discrete control settings :
# * "Taxi-v3" : episodic & discrete setting both for states and actions (S/N/E/W/Pickup/Dropoff)
# * __"CartPole-v0" / "CartPole-v1" : discrete action and continuous state space__
# * __"MountainCar-v0" : discrete action and continuous state space__
#
# Continous control settings :
# * __"MountainCarContinuous-v0" (both state and action continuous spaces)__
# * "LunarLanderContinuous-v2" (requires box2D)
# * "CarRacing-v0" : "Discrete control is reasonable in this environment as well" (requires box2D)
#
# * "MsPacman-v0 "(requires the Atari dependency)
#
# Settings used by the authors (requires the MuJoCo dependencies, 30 days free trial) : https://github.com/openai/mujoco-py
# * "HalfCheetah-v1" (use v2 now?)
# * "Hopper-v1"
# * etc.

# %% [markdown]
# ## Configuration

# %% [markdown]
# See https://github.com/llSourcell/Unity_ML_Agents/blob/master/docs/best-practices-ppo.md for tuning best practice

# %%
config = reset_config(print_=True)
# Out:
# Training config :
#
# {'actor_network': {'lr': 0.001},
#  'batch_size': 2048,
#  'beta_KL': 3,
#  'c1': 1,
#  'c2': 0.001,
#  'color': {'A2C_loss': (0.4, 0.7607843137254902, 0.6470588235294118),
#            'adaptative_KL_loss': (0.9882352941176471,
#                                   0.5529411764705883,
#                                   0.3843137254901961),
#            'clipped_loss': (0.5529411764705883,
#                             0.6274509803921569,
#                             0.796078431372549)},
#  'd_targ': 0.01,
#  'env': 'CartPole-v1',
#  'epochs': 4,
#  'eps_clipping': 0.2,
#  'gamma': 0.99,
#  'lambda': 1,
#  'loss_name': 'clipped_loss',
#  'max_episodes': 1000,
#  'max_steps': 300,
#  'optimize_every': 2048,
#  'randomize_batch': False,
#  'reset_val': None,
#  'reward_norm': False,
#  'seed': 42,
#  'solved_reward': {'CartPole-v1': 300,
#                    'LunarLander-v2': 230,
#                    'MountainCar-v0': 300,
#                    'MountainCarContinuous-v0': 300},
#  'std': 0.001,
#  'value_network': {'lr': 0.001}}

# %% [markdown]
# # Lunar

# %%
#config["reward_norm"]=True
print(config["lambda"]!=1)
config['env'] = 'LunarLander-v2'
config['batch_size'] = 2048
rewards_list = []
loss_list = []
for loss in ["clipped_loss","adaptative_KL_loss","A2C_loss"]:
    print("-----------------"+loss+"-----------------")
    config["loss_name"]=loss
    print(config)
    agent = PPOAgent(config)
    
    rewards, loss = agent.training(config["epochs"], config["optimize_every"], config["max_episodes"], config["max_steps"])
    rewards_list.append(rewards)
    loss_list.append(loss)
# Out:
# False
# -----------------clipped_loss-----------------
# {'env': 'LunarLander-v2', 'std': 0.001, 'gamma': 0.99, 'lambda': 1, 'value_network': {'lr': 0.001}, 'actor_network': {'lr': 0.001}, 'eps_clipping': 0.2, 'd_targ': 0.01, 'beta_KL': 3, 'c1': 1, 'c2': 0.001, 'reward_norm': False, 'epochs': 4, 'max_episodes': 1000, 'max_steps': 300, 'optimize_every': 2048, 'batch_size': 2048, 'loss_name': 'clipped_loss', 'color': {'A2C_loss': (0.4, 0.7607843137254902, 0.6470588235294118), 'adaptative_KL_loss': (0.9882352941176471, 0.5529411764705883, 0.3843137254901961), 'clipped_loss': (0.5529411764705883, 0.6274509803921569, 0.796078431372549)}, 'seed': 42, 'reset_val': None, 'solved_reward': {'LunarLander-v2': 230, 'MountainCarContinuous-v0': 300, 'CartPole-v1': 300, 'MountainCar-v0': 300}}
# Loss :  clipped_loss
# Episode 1/1000: Mean rewards: -214.28, Std: 123.44
# Episode 25/1000: Mean rewards: -184.03, Std: 103.64
# Episode 50/1000: Mean rewards: -174.02, Std: 100.78
# Episode 75/1000: Mean rewards: -185.4, Std: 108.37
# Episode 100/1000: Mean rewards: -175.33, Std: 111.81
# Episode 125/1000: Mean rewards: -157.01, Std: 86.42
# Episode 150/1000: Mean rewards: -158.01, Std: 77.64
# Episode 175/1000: Mean rewards: -144.79, Std: 69.03
# Episode 200/1000: Mean rewards: -158.04, Std: 79.14
# Episode 225/1000: Mean rewards: -172.82, Std: 98.8
# Episode 250/1000: Mean rewards: -171.42, Std: 69.1
# Episode 275/1000: Mean rewards: -163.67, Std: 87.97
# Episode 300/1000: Mean rewards: -162.86, Std: 73.48
# Episode 325/1000: Mean rewards: -140.21, Std: 56.63
# Episode 350/1000: Mean rewards: -143.55, Std: 68.71
# Episode 375/1000: Mean rewards: -113.79, Std: 50.55
# Episode 400/1000: Mean rewards: -149.5, Std: 77.34
# Episode 425/1000: Mean rewards: -156.86, Std: 97.36
# Episode 450/1000: Mean rewards: -133.01, Std: 74.1
# Episode 475/1000: Mean rewards: -136.29, Std: 76.87
# Episode 500/1000: Mean rewards: -143.89, Std: 78.28
# Episode 525/1000: Mean rewards: -154.6, Std: 80.76
# Episode 550/1000: Mean rewards: -159.24, Std: 72.32
# Episode 575/1000: Mean rewards: -168.71, Std: 91.02
# Episode 600/1000: Mean rewards: -172.17, Std: 104.53
# Episode 625/1000: Mean rewards: -190.87, Std: 98.12
# Episode 650/1000: Mean rewards: -169.82, Std: 105.87
# Episode 675/1000: Mean rewards: -163.36, Std: 95.84
# Episode 700/1000: Mean rewards: -152.3, Std: 77.31
# Episode 725/1000: Mean rewards: -152.99, Std: 84.57
# Episode 750/1000: Mean rewards: -155.26, Std: 77.99
# Episode 775/1000: Mean rewards: -144.5, Std: 87.65
# Episode 800/1000: Mean rewards: -149.27, Std: 88.71
# Episode 825/1000: Mean rewards: -147.06, Std: 99.41
# Episode 850/1000: Mean rewards: -165.39, Std: 92.92
# Episode 875/1000: Mean rewards: -163.01, Std: 92.22
# Episode 900/1000: Mean rewards: -149.03, Std: 91.32
# Episode 925/1000: Mean rewards: -157.79, Std: 95.47
# Episode 950/1000: Mean rewards: -142.23, Std: 85.08
# Episode 975/1000: Mean rewards: -124.34, Std: 58.89
# Episode 999/1000: Mean rewards: -141.8, Std: 78.62
# The training was done over a total of 1000 episodes
# Total time ellapsed during training :  0:01:18.443224
# -----------------adaptative_KL_loss-----------------
# {'env': 'LunarLander-v2', 'std': 0.001, 'gamma': 0.99, 'lambda': 1, 'value_network': {'lr': 0.001}, 'actor_network': {'lr': 0.001}, 'eps_clipping': 0.2, 'd_targ': 0.01, 'beta_KL': 3, 'c1': 1, 'c2': 0.001, 'reward_norm': False, 'epochs': 4, 'max_episodes': 1000, 'max_steps': 300, 'optimize_every': 2048, 'batch_size': 2048, 'loss_name': 'adaptative_KL_loss', 'color': {'A2C_loss': (0.4, 0.7607843137254902, 0.6470588235294118), 'adaptative_KL_loss': (0.9882352941176471, 0.5529411764705883, 0.3843137254901961), 'clipped_loss': (0.5529411764705883, 0.6274509803921569, 0.796078431372549)}, 'seed': 42, 'reset_val': None, 'solved_reward': {'LunarLander-v2': 230, 'MountainCarContinuous-v0': 300, 'CartPole-v1': 300, 'MountainCar-v0': 300}}
# Loss :  adaptative_KL_loss
# Episode 1/1000: Mean rewards: -214.28, Std: 123.44
# Episode 25/1000: Mean rewards: -187.04, Std: 110.31
# Episode 50/1000: Mean rewards: -169.22, Std: 100.91
# Episode 75/1000: Mean rewards: -176.08, Std: 124.52
# Episode 100/1000: Mean rewards: -158.58, Std: 90.93
# Episode 125/1000: Mean rewards: -169.66, Std: 92.17
# Episode 150/1000: Mean rewards: -159.56, Std: 84.4
# Episode 175/1000: Mean rewards: -141.87, Std: 68.22
# Episode 200/1000: Mean rewards: -122.65, Std: 45.72
# Episode 225/1000: Mean rewards: -155.77, Std: 72.24
# Episode 250/1000: Mean rewards: -146.05, Std: 85.3
# Episode 275/1000: Mean rewards: -145.28, Std: 83.05
# Episode 300/1000: Mean rewards: -127.56, Std: 49.56
# Episode 325/1000: Mean rewards: -116.72, Std: 49.82
# Episode 350/1000: Mean rewards: -124.13, Std: 58.07
# Episode 375/1000: Mean rewards: -127.85, Std: 49.27
# Episode 400/1000: Mean rewards: -120.69, Std: 54.52
# Episode 425/1000: Mean rewards: -133.55, Std: 61.36
# Episode 450/1000: Mean rewards: -154.16, Std: 80.5
# Episode 475/1000: Mean rewards: -134.69, Std: 60.07
# Episode 500/1000: Mean rewards: -127.32, Std: 69.72
# Episode 525/1000: Mean rewards: -145.13, Std: 57.22
# Episode 550/1000: Mean rewards: -137.82, Std: 82.23
# Episode 575/1000: Mean rewards: -137.74, Std: 64.08
# Episode 600/1000: Mean rewards: -123.29, Std: 70.37
# Episode 625/1000: Mean rewards: -132.35, Std: 60.97
# Episode 650/1000: Mean rewards: -125.42, Std: 45.03
# Episode 675/1000: Mean rewards: -118.94, Std: 51.32
# Episode 700/1000: Mean rewards: -148.38, Std: 93.95
# Episode 725/1000: Mean rewards: -154.37, Std: 100.3
# Episode 750/1000: Mean rewards: -160.66, Std: 94.33
# Episode 775/1000: Mean rewards: -166.15, Std: 91.59
# Episode 800/1000: Mean rewards: -165.46, Std: 86.41
# Episode 825/1000: Mean rewards: -141.47, Std: 75.24
# Episode 850/1000: Mean rewards: -133.96, Std: 69.69
# Episode 875/1000: Mean rewards: -133.81, Std: 80.93
# Episode 900/1000: Mean rewards: -118.48, Std: 56.08
# Episode 925/1000: Mean rewards: -108.07, Std: 35.76
# Episode 950/1000: Mean rewards: -104.13, Std: 41.32
# Episode 975/1000: Mean rewards: -100.85, Std: 50.12
# Episode 999/1000: Mean rewards: -111.59, Std: 40.23
# The training was done over a total of 1000 episodes
# Total time ellapsed during training :  0:01:31.066668
# -----------------A2C_loss-----------------
# {'env': 'LunarLander-v2', 'std': 0.001, 'gamma': 0.99, 'lambda': 1, 'value_network': {'lr': 0.001}, 'actor_network': {'lr': 0.001}, 'eps_clipping': 0.2, 'd_targ': 0.01, 'beta_KL': 3, 'c1': 1, 'c2': 0.001, 'reward_norm': False, 'epochs': 4, 'max_episodes': 1000, 'max_steps': 300, 'optimize_every': 2048, 'batch_size': 2048, 'loss_name': 'A2C_loss', 'color': {'A2C_loss': (0.4, 0.7607843137254902, 0.6470588235294118), 'adaptative_KL_loss': (0.9882352941176471, 0.5529411764705883, 0.3843137254901961), 'clipped_loss': (0.5529411764705883, 0.6274509803921569, 0.796078431372549)}, 'seed': 42, 'reset_val': None, 'solved_reward': {'LunarLander-v2': 230, 'MountainCarContinuous-v0': 300, 'CartPole-v1': 300, 'MountainCar-v0': 300}}
# Loss :  A2C_loss
# Episode 1/1000: Mean rewards: -214.28, Std: 123.44
# Episode 25/1000: Mean rewards: -192.9, Std: 120.92
# Episode 50/1000: Mean rewards: -167.87, Std: 83.5
# Episode 75/1000: Mean rewards: -182.75, Std: 120.52
# Episode 100/1000: Mean rewards: -198.58, Std: 108.07
# Episode 125/1000: Mean rewards: -190.8, Std: 110.51
# Episode 150/1000: Mean rewards: -146.01, Std: 65.85
# Episode 175/1000: Mean rewards: -132.57, Std: 52.37
# Episode 200/1000: Mean rewards: -158.1, Std: 79.88
# Episode 225/1000: Mean rewards: -160.04, Std: 69.98
# Episode 250/1000: Mean rewards: -149.9, Std: 74.78
# Episode 275/1000: Mean rewards: -164.93, Std: 71.1
# Episode 300/1000: Mean rewards: -161.64, Std: 83.23
# Episode 325/1000: Mean rewards: -151.97, Std: 50.74
# Episode 350/1000: Mean rewards: -147.14, Std: 53.79
# Episode 375/1000: Mean rewards: -145.18, Std: 64.49
# Episode 400/1000: Mean rewards: -140.56, Std: 44.48
# Episode 425/1000: Mean rewards: -133.23, Std: 35.06
# Episode 450/1000: Mean rewards: -133.37, Std: 34.08
# Episode 475/1000: Mean rewards: -122.93, Std: 45.26
# Episode 500/1000: Mean rewards: -124.6, Std: 32.41
# Episode 525/1000: Mean rewards: -129.87, Std: 41.17
# Episode 550/1000: Mean rewards: -140.68, Std: 41.98
# Episode 575/1000: Mean rewards: -124.61, Std: 35.65
# Episode 600/1000: Mean rewards: -129.61, Std: 39.44
# Episode 625/1000: Mean rewards: -130.07, Std: 54.24
# Episode 650/1000: Mean rewards: -144.29, Std: 57.09
# Episode 675/1000: Mean rewards: -137.01, Std: 38.54
# Episode 700/1000: Mean rewards: -129.76, Std: 40.48
# Episode 725/1000: Mean rewards: -125.95, Std: 40.03
# Episode 750/1000: Mean rewards: -121.54, Std: 50.88
# Episode 775/1000: Mean rewards: -132.03, Std: 41.31
# Episode 800/1000: Mean rewards: -137.04, Std: 48.91
# Episode 825/1000: Mean rewards: -126.75, Std: 42.41
# Episode 850/1000: Mean rewards: -132.18, Std: 36.03
# Episode 875/1000: Mean rewards: -126.27, Std: 42.04
# Episode 900/1000: Mean rewards: -124.07, Std: 37.1
# Episode 925/1000: Mean rewards: -137.65, Std: 44.35
# Episode 950/1000: Mean rewards: -129.0, Std: 55.73
# Episode 975/1000: Mean rewards: -131.16, Std: 37.84
# Episode 999/1000: Mean rewards: -141.93, Std: 44.28
# The training was done over a total of 1000 episodes
# Total time ellapsed during training :  0:01:30.507160

# %%
plot_sumup(rewards_list,loss_list,config=config)

# %% [markdown]
# # Cartpole

# %%
config["env"] = 'CartPole-v1'
print(config["lambda"]!=1)
#config["batch_size"] = 128
rewards_list = []
loss_list = []
for loss in ["clipped_loss","adaptative_KL_loss","A2C_loss"]:
    print("-----------------"+loss+"-----------------")
    config["loss_name"]=loss
    print(config)
    agent = PPOAgent(config)
    
    rewards, loss = agent.training(config["epochs"], config["optimize_every"], config["max_episodes"], config["max_steps"])
    rewards_list.append(rewards)
    loss_list.append(loss)
# Out:
# False
# -----------------clipped_loss-----------------
# {'env': 'CartPole-v1', 'std': 0.001, 'gamma': 0.99, 'lambda': 1, 'value_network': {'lr': 0.001}, 'actor_network': {'lr': 0.001}, 'eps_clipping': 0.2, 'd_targ': 0.01, 'beta_KL': 3, 'c1': 1, 'c2': 0.001, 'reward_norm': False, 'epochs': 4, 'max_episodes': 1000, 'max_steps': 300, 'optimize_every': 2048, 'batch_size': 128, 'randomize_batch': False, 'seed': 42, 'loss_name': 'clipped_loss', 'color': {'A2C_loss': (0.4, 0.7607843137254902, 0.6470588235294118), 'adaptative_KL_loss': (0.9882352941176471, 0.5529411764705883, 0.3843137254901961), 'clipped_loss': (0.5529411764705883, 0.6274509803921569, 0.796078431372549)}, 'solved_reward': {'LunarLander-v2': 230, 'MountainCarContinuous-v0': 300, 'CartPole-v1': 300, 'MountainCar-v0': 300}, 'reset_val': None}
# Loss :  clipped_loss
# Episode 1/1000: Mean rewards: 19.9, Std: 8.5
# Episode 25/1000: Mean rewards: 20.08, Std: 8.08
# Episode 50/1000: Mean rewards: 20.7, Std: 10.55
# Episode 75/1000: Mean rewards: 21.22, Std: 11.71
# Episode 100/1000: Mean rewards: 25.22, Std: 11.75
# Episode 125/1000: Mean rewards: 29.34, Std: 15.99
# Episode 150/1000: Mean rewards: 27.0, Std: 17.2
# Episode 175/1000: Mean rewards: 39.92, Std: 24.27
# Episode 200/1000: Mean rewards: 45.84, Std: 30.88
# Episode 225/1000: Mean rewards: 41.36, Std: 27.83
# Episode 250/1000: Mean rewards: 41.82, Std: 26.47
# Episode 275/1000: Mean rewards: 37.38, Std: 24.15
# Episode 300/1000: Mean rewards: 36.28, Std: 17.36
# Episode 325/1000: Mean rewards: 35.28, Std: 25.01
# Episode 350/1000: Mean rewards: 34.34, Std: 18.49
# Episode 375/1000: Mean rewards: 34.86, Std: 21.9
# Episode 400/1000: Mean rewards: 28.14, Std: 17.96
# Episode 425/1000: Mean rewards: 24.38, Std: 15.63
# Episode 450/1000: Mean rewards: 22.94, Std: 12.83
# Episode 475/1000: Mean rewards: 25.12, Std: 14.81
# Episode 500/1000: Mean rewards: 22.94, Std: 13.28
# Episode 525/1000: Mean rewards: 10.52, Std: 1.54
# Episode 550/1000: Mean rewards: 10.38, Std: 1.79
# Episode 575/1000: Mean rewards: 10.52, Std: 1.51
# Episode 600/1000: Mean rewards: 10.46, Std: 1.47
# Episode 625/1000: Mean rewards: 10.46, Std: 1.15
# Episode 650/1000: Mean rewards: 10.62, Std: 1.71
# Episode 675/1000: Mean rewards: 10.68, Std: 1.53
# Episode 700/1000: Mean rewards: 9.22, Std: 0.73
# Episode 725/1000: Mean rewards: 9.36, Std: 0.69
# Episode 750/1000: Mean rewards: 9.22, Std: 0.67
# Episode 775/1000: Mean rewards: 9.36, Std: 0.74
# Episode 800/1000: Mean rewards: 9.28, Std: 0.8
# Episode 825/1000: Mean rewards: 9.36, Std: 0.69
# Episode 850/1000: Mean rewards: 9.34, Std: 0.76
# Episode 875/1000: Mean rewards: 9.46, Std: 0.73
# Episode 900/1000: Mean rewards: 9.34, Std: 0.74
# Episode 925/1000: Mean rewards: 9.2, Std: 0.75
# Episode 950/1000: Mean rewards: 9.34, Std: 0.79
# Episode 975/1000: Mean rewards: 9.24, Std: 0.71
# Episode 999/1000: Mean rewards: 9.5, Std: 0.7
# The training was done over a total of 1000 episodes
# Total time ellapsed during training :  0:00:17.215818
# -----------------adaptative_KL_loss-----------------
# {'env': 'CartPole-v1', 'std': 0.001, 'gamma': 0.99, 'lambda': 1, 'value_network': {'lr': 0.001}, 'actor_network': {'lr': 0.001}, 'eps_clipping': 0.2, 'd_targ': 0.01, 'beta_KL': 3, 'c1': 1, 'c2': 0.001, 'reward_norm': False, 'epochs': 4, 'max_episodes': 1000, 'max_steps': 300, 'optimize_every': 2048, 'batch_size': 128, 'randomize_batch': False, 'seed': 42, 'loss_name': 'adaptative_KL_loss', 'color': {'A2C_loss': (0.4, 0.7607843137254902, 0.6470588235294118), 'adaptative_KL_loss': (0.9882352941176471, 0.5529411764705883, 0.3843137254901961), 'clipped_loss': (0.5529411764705883, 0.6274509803921569, 0.796078431372549)}, 'solved_reward': {'LunarLander-v2': 230, 'MountainCarContinuous-v0': 300, 'CartPole-v1': 300, 'MountainCar-v0': 300}, 'reset_val': None}
# Loss :  adaptative_KL_loss
# Episode 1/1000: Mean rewards: 19.9, Std: 8.5
# Episode 25/1000: Mean rewards: 20.08, Std: 8.08
# Episode 50/1000: Mean rewards: 20.7, Std: 10.55
# Episode 75/1000: Mean rewards: 21.22, Std: 11.71
# Episode 100/1000: Mean rewards: 61.14, Std: 35.63
# Episode 125/1000: Mean rewards: 59.34, Std: 9.43
# Episode 150/1000: Mean rewards: 62.26, Std: 11.4
# Episode 175/1000: Mean rewards: 70.02, Std: 22.74
# Episode 200/1000: Mean rewards: 115.72, Std: 12.12
# Episode 225/1000: Mean rewards: 139.14, Std: 14.81
# Episode 250/1000: Mean rewards: 136.24, Std: 18.44
# Episode 275/1000: Mean rewards: 158.68, Std: 27.32
# Episode 300/1000: Mean rewards: 93.22, Std: 37.09
# Episode 325/1000: Mean rewards: 186.0, Std: 111.18
# Episode 350/1000: Mean rewards: 190.44, Std: 74.62
# Episode 375/1000: Mean rewards: 178.3, Std: 84.97
# Episode 400/1000: Mean rewards: 154.06, Std: 68.2
# Episode 425/1000: Mean rewards: 166.56, Std: 80.89
# Episode 450/1000: Mean rewards: 204.38, Std: 76.96
# Episode 475/1000: Mean rewards: 233.42, Std: 12.43
# Episode 500/1000: Mean rewards: 474.56, Std: 39.68
# Episode 525/1000: Mean rewards: 329.82, Std: 44.7
# Episode 550/1000: Mean rewards: 320.94, Std: 52.69
# Episode 575/1000: Mean rewards: 238.86, Std: 19.0
# Episode 600/1000: Mean rewards: 244.98, Std: 26.55
# Episode 625/1000: Mean rewards: 215.48, Std: 44.6
# Episode 650/1000: Mean rewards: 188.4, Std: 41.52
# Episode 675/1000: Mean rewards: 143.5, Std: 25.58
# Episode 700/1000: Mean rewards: 80.5, Std: 17.51
# Episode 725/1000: Mean rewards: 17.68, Std: 2.41
# Episode 750/1000: Mean rewards: 17.22, Std: 2.48
# Episode 775/1000: Mean rewards: 17.84, Std: 2.63
# Episode 800/1000: Mean rewards: 17.0, Std: 2.47
# Episode 825/1000: Mean rewards: 10.88, Std: 1.18
# Episode 850/1000: Mean rewards: 11.22, Std: 1.43
# Episode 875/1000: Mean rewards: 11.2, Std: 1.26
# Episode 900/1000: Mean rewards: 10.96, Std: 1.47
# Episode 925/1000: Mean rewards: 10.94, Std: 1.38
# Episode 950/1000: Mean rewards: 11.22, Std: 1.45
# Episode 975/1000: Mean rewards: 10.94, Std: 1.22
# Episode 999/1000: Mean rewards: 11.32, Std: 1.32
# The training was done over a total of 1000 episodes
# Total time ellapsed during training :  0:01:27.706646
# -----------------A2C_loss-----------------
# {'env': 'CartPole-v1', 'std': 0.001, 'gamma': 0.99, 'lambda': 1, 'value_network': {'lr': 0.001}, 'actor_network': {'lr': 0.001}, 'eps_clipping': 0.2, 'd_targ': 0.01, 'beta_KL': 3, 'c1': 1, 'c2': 0.001, 'reward_norm': False, 'epochs': 4, 'max_episodes': 1000, 'max_steps': 300, 'optimize_every': 2048, 'batch_size': 128, 'randomize_batch': False, 'seed': 42, 'loss_name': 'A2C_loss', 'color': {'A2C_loss': (0.4, 0.7607843137254902, 0.6470588235294118), 'adaptative_KL_loss': (0.9882352941176471, 0.5529411764705883, 0.3843137254901961), 'clipped_loss': (0.5529411764705883, 0.6274509803921569, 0.796078431372549)}, 'solved_reward': {'LunarLander-v2': 230, 'MountainCarContinuous-v0': 300, 'CartPole-v1': 300, 'MountainCar-v0': 300}, 'reset_val': None}
# Loss :  A2C_loss
# Episode 1/1000: Mean rewards: 19.9, Std: 8.5
# Episode 25/1000: Mean rewards: 20.08, Std: 8.08
# Episode 50/1000: Mean rewards: 20.7, Std: 10.55
# Episode 75/1000: Mean rewards: 21.22, Std: 11.71
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-14-44aaf64d1df0> in <module>
#      10     agent = PPOAgent(config)
#      11
# ---> 12     rewards, loss = agent.training(config["epochs"], config["optimize_every"], config["max_episodes"], config["max_steps"])
#      13     rewards_list.append(rewards)
#      14     loss_list.append(loss)
#
# ~/Documents/RL-PPO/PPO3/ppo.py in training(self, epochs, optimize_every, max_episodes, max_steps)
#     181                         #loss_val, dry_loss_val, entrop_val = self.optimize_model(returns_, advantages_)
#     182                         ##loss_val, dry_loss_val, entrop_val = self.optimize_model(obs, epoch)
# --> 183                         loss_val, dry_loss_val, entrop_val = self.optimize_model(obs)
#     184                         # only save result of last epoch #?? save more for fine tuning nb of epochs ??
#     185                         if epoch == epochs-1 :
#
# ~/Documents/RL-PPO/PPO3/ppo.py in optimize_model(self, next_obs)
#     399             #print(entropy_term)
#     400             #print(entropy_term.size())
# --> 401             loss -= (self.c2 * entropy_term)
#     402             loss = loss / n_trajs
#     403
#
# RuntimeError: output with shape [] doesn't match the broadcast shape [128]

# %%
#PPO VERSION 1
plot_sumup(rewards_list,loss_list,config=config)

# %%
#PPO VERSION 1
plot_sumup(rewards_list,loss_list,config=config)

# %%
config["env"] = 'CartPole-v1'
print(config["lambda"]!=1)
config["batch_size"] = 128
rewards_list = []
loss_list = []
for loss in ["clipped_loss","adaptative_KL_loss","A2C_loss"]:
    print("-----------------"+loss+"-----------------")
    config["loss_name"]=loss
    print(config)
    agent = PPOAgent(config)
    
    rewards, loss = agent.training(config["epochs"], config["optimize_every"], config["max_episodes"], config["max_steps"])
    rewards_list.append(rewards)
    loss_list.append(loss)
# Out:
# False
# -----------------clipped_loss-----------------
# {'env': 'CartPole-v1', 'std': 0.001, 'gamma': 0.99, 'lambda': 1, 'value_network': {'lr': 0.001}, 'actor_network': {'lr': 0.001}, 'eps_clipping': 0.2, 'd_targ': 0.01, 'beta_KL': 3, 'c1': 1, 'c2': 0.001, 'reward_norm': False, 'epochs': 4, 'max_episodes': 1000, 'max_steps': 300, 'optimize_every': 2048, 'batch_size': 128, 'randomize_batch': False, 'seed': 42, 'loss_name': 'clipped_loss', 'color': {'A2C_loss': (0.4, 0.7607843137254902, 0.6470588235294118), 'adaptative_KL_loss': (0.9882352941176471, 0.5529411764705883, 0.3843137254901961), 'clipped_loss': (0.5529411764705883, 0.6274509803921569, 0.796078431372549)}, 'solved_reward': {'LunarLander-v2': 230, 'MountainCarContinuous-v0': 300, 'CartPole-v1': 300, 'MountainCar-v0': 300}, 'reset_val': None}
# Loss :  clipped_loss
# Episode 1/1000: Mean rewards: 19.9, Std: 8.5
# Episode 25/1000: Mean rewards: 20.08, Std: 8.08
# Episode 50/1000: Mean rewards: 20.7, Std: 10.55
# Episode 75/1000: Mean rewards: 21.22, Std: 11.71
# Episode 100/1000: Mean rewards: 25.22, Std: 11.75
# Episode 125/1000: Mean rewards: 29.34, Std: 15.99
# Episode 150/1000: Mean rewards: 27.0, Std: 17.2
# Episode 175/1000: Mean rewards: 39.92, Std: 24.27
# Episode 200/1000: Mean rewards: 45.84, Std: 30.88
# Episode 225/1000: Mean rewards: 40.82, Std: 33.67
# Episode 250/1000: Mean rewards: 44.06, Std: 35.12
# Episode 275/1000: Mean rewards: 34.76, Std: 22.69
# Episode 300/1000: Mean rewards: 31.72, Std: 15.21
# Episode 325/1000: Mean rewards: 36.1, Std: 22.77
# Episode 350/1000: Mean rewards: 29.14, Std: 18.87
# Episode 375/1000: Mean rewards: 30.6, Std: 16.52
# Episode 400/1000: Mean rewards: 37.3, Std: 24.32
# Episode 425/1000: Mean rewards: 34.62, Std: 22.14
# Episode 450/1000: Mean rewards: 34.04, Std: 22.32
# Episode 475/1000: Mean rewards: 34.98, Std: 20.74
# Episode 500/1000: Mean rewards: 39.3, Std: 22.74
# Episode 525/1000: Mean rewards: 39.08, Std: 23.76
# Episode 550/1000: Mean rewards: 29.56, Std: 17.96
# Episode 575/1000: Mean rewards: 26.6, Std: 12.5
# Episode 600/1000: Mean rewards: 28.7, Std: 20.54
# Episode 625/1000: Mean rewards: 30.06, Std: 22.77
# Episode 650/1000: Mean rewards: 29.58, Std: 16.66
# Episode 675/1000: Mean rewards: 32.74, Std: 24.92
# Episode 700/1000: Mean rewards: 25.74, Std: 13.27
# Episode 725/1000: Mean rewards: 25.4, Std: 15.75
# Episode 750/1000: Mean rewards: 30.98, Std: 18.47
# Episode 775/1000: Mean rewards: 32.08, Std: 21.2
# Episode 800/1000: Mean rewards: 25.68, Std: 14.56
# Episode 825/1000: Mean rewards: 24.06, Std: 13.78
# Episode 850/1000: Mean rewards: 29.3, Std: 17.1
# Episode 875/1000: Mean rewards: 32.44, Std: 17.56
# Episode 900/1000: Mean rewards: 28.78, Std: 17.31
# Episode 925/1000: Mean rewards: 31.46, Std: 20.35
# Episode 950/1000: Mean rewards: 27.28, Std: 16.35
# Episode 975/1000: Mean rewards: 28.34, Std: 15.25
# Episode 999/1000: Mean rewards: 27.86, Std: 16.69
# The training was done over a total of 1000 episodes
# Total time ellapsed during training :  0:00:24.386440
# -----------------adaptative_KL_loss-----------------
# {'env': 'CartPole-v1', 'std': 0.001, 'gamma': 0.99, 'lambda': 1, 'value_network': {'lr': 0.001}, 'actor_network': {'lr': 0.001}, 'eps_clipping': 0.2, 'd_targ': 0.01, 'beta_KL': 3, 'c1': 1, 'c2': 0.001, 'reward_norm': False, 'epochs': 4, 'max_episodes': 1000, 'max_steps': 300, 'optimize_every': 2048, 'batch_size': 128, 'randomize_batch': False, 'seed': 42, 'loss_name': 'adaptative_KL_loss', 'color': {'A2C_loss': (0.4, 0.7607843137254902, 0.6470588235294118), 'adaptative_KL_loss': (0.9882352941176471, 0.5529411764705883, 0.3843137254901961), 'clipped_loss': (0.5529411764705883, 0.6274509803921569, 0.796078431372549)}, 'solved_reward': {'LunarLander-v2': 230, 'MountainCarContinuous-v0': 300, 'CartPole-v1': 300, 'MountainCar-v0': 300}, 'reset_val': None}
# Loss :  adaptative_KL_loss
# Episode 1/1000: Mean rewards: 19.9, Std: 8.5
# Episode 25/1000: Mean rewards: 20.08, Std: 8.08
# Episode 50/1000: Mean rewards: 20.7, Std: 10.55
# Episode 75/1000: Mean rewards: 21.22, Std: 11.71
# Episode 100/1000: Mean rewards: 61.14, Std: 35.63
# Episode 125/1000: Mean rewards: 59.34, Std: 9.43
# Episode 150/1000: Mean rewards: 62.26, Std: 11.4
# Episode 175/1000: Mean rewards: 70.02, Std: 22.74
# Episode 200/1000: Mean rewards: 115.72, Std: 12.12
# Episode 225/1000: Mean rewards: 136.62, Std: 16.05
# Episode 250/1000: Mean rewards: 194.22, Std: 44.37
# Episode 275/1000: Mean rewards: 206.24, Std: 52.87
# Episode 300/1000: Mean rewards: 176.3, Std: 31.8
# Episode 325/1000: Mean rewards: 216.16, Std: 37.25
# Episode 350/1000: Mean rewards: 160.26, Std: 26.06
# Episode 375/1000: Mean rewards: 171.52, Std: 25.41
# Episode 400/1000: Mean rewards: 159.84, Std: 31.38
# Episode 425/1000: Mean rewards: 147.12, Std: 36.08
# Episode 450/1000: Mean rewards: 56.98, Std: 10.25
# Episode 475/1000: Mean rewards: 57.96, Std: 10.7
# Episode 500/1000: Mean rewards: 37.82, Std: 12.66
# Episode 525/1000: Mean rewards: 36.02, Std: 12.78
# Episode 550/1000: Mean rewards: 11.48, Std: 1.17
# Episode 575/1000: Mean rewards: 11.56, Std: 1.13
# Episode 600/1000: Mean rewards: 11.46, Std: 1.24
# Episode 625/1000: Mean rewards: 11.38, Std: 1.18
# Episode 650/1000: Mean rewards: 11.52, Std: 1.12
# Episode 675/1000: Mean rewards: 11.44, Std: 1.06
# Episode 700/1000: Mean rewards: 11.24, Std: 1.27
# Episode 725/1000: Mean rewards: 9.36, Std: 0.69
# Episode 750/1000: Mean rewards: 9.22, Std: 0.67
# Episode 775/1000: Mean rewards: 9.36, Std: 0.74
# Episode 800/1000: Mean rewards: 9.28, Std: 0.8
# Episode 825/1000: Mean rewards: 9.36, Std: 0.69
# Episode 850/1000: Mean rewards: 9.34, Std: 0.76
# Episode 875/1000: Mean rewards: 9.46, Std: 0.73
# Episode 900/1000: Mean rewards: 9.34, Std: 0.74
# Episode 925/1000: Mean rewards: 9.2, Std: 0.75
# Episode 950/1000: Mean rewards: 9.34, Std: 0.79
# Episode 975/1000: Mean rewards: 9.24, Std: 0.71
# Episode 999/1000: Mean rewards: 9.5, Std: 0.7
# The training was done over a total of 1000 episodes
# Total time ellapsed during training :  0:00:48.931095
# -----------------A2C_loss-----------------
# {'env': 'CartPole-v1', 'std': 0.001, 'gamma': 0.99, 'lambda': 1, 'value_network': {'lr': 0.001}, 'actor_network': {'lr': 0.001}, 'eps_clipping': 0.2, 'd_targ': 0.01, 'beta_KL': 3, 'c1': 1, 'c2': 0.001, 'reward_norm': False, 'epochs': 4, 'max_episodes': 1000, 'max_steps': 300, 'optimize_every': 2048, 'batch_size': 128, 'randomize_batch': False, 'seed': 42, 'loss_name': 'A2C_loss', 'color': {'A2C_loss': (0.4, 0.7607843137254902, 0.6470588235294118), 'adaptative_KL_loss': (0.9882352941176471, 0.5529411764705883, 0.3843137254901961), 'clipped_loss': (0.5529411764705883, 0.6274509803921569, 0.796078431372549)}, 'solved_reward': {'LunarLander-v2': 230, 'MountainCarContinuous-v0': 300, 'CartPole-v1': 300, 'MountainCar-v0': 300}, 'reset_val': None}
# Loss :  A2C_loss
# Episode 1/1000: Mean rewards: 19.9, Std: 8.5
# Episode 25/1000: Mean rewards: 20.08, Std: 8.08
# Episode 50/1000: Mean rewards: 20.7, Std: 10.55
# Episode 75/1000: Mean rewards: 21.22, Std: 11.71
# Episode 100/1000: Mean rewards: 34.12, Std: 18.62
# Episode 125/1000: Mean rewards: 34.58, Std: 25.74
# Episode 150/1000: Mean rewards: 34.6, Std: 18.35
# Episode 175/1000: Mean rewards: 168.52, Std: 75.85
# Episode 200/1000: Mean rewards: 199.5, Std: 68.48
# Episode 225/1000: Mean rewards: 249.66, Std: 63.09
# Episode 250/1000: Mean rewards: 248.06, Std: 63.78
# Episode 275/1000: Mean rewards: 454.58, Std: 75.66
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-44aaf64d1df0> in <module>
#      10     agent = PPOAgent(config)
#      11
# ---> 12     rewards, loss = agent.training(config["epochs"], config["optimize_every"], config["max_episodes"], config["max_steps"])
#      13     rewards_list.append(rewards)
#      14     loss_list.append(loss)
#
# ~/Documents/RL-PPO/PPO3/ppo.py in training(self, epochs, optimize_every, max_episodes, max_steps)
#     181                         #loss_val, dry_loss_val, entrop_val = self.optimize_model(returns_, advantages_)
#     182                         ##loss_val, dry_loss_val, entrop_val = self.optimize_model(obs, epoch)
# --> 183                         loss_val, dry_loss_val, entrop_val = self.optimize_model(obs)
#     184                         # only save result of last epoch #?? save more for fine tuning nb of epochs ??
#     185                         if epoch == epochs-1 :
#
# ~/Documents/RL-PPO/PPO3/ppo.py in optimize_model(self, next_obs)
#     336         next_value = self.value_network.predict(next_obs)
#     337         values = self.value_network(observations)#.detach()#[permutation]
# --> 338         returns, advantages = self._returns_advantages(values, next_value)
#     339         returns = returns.float().to(self.device)#.detach()
#     340         advantages = advantages.float().to(self.device)#.detach()
#
# ~/Documents/RL-PPO/PPO3/ppo.py in _returns_advantages(self, values, next_value)
#     100             # build the advantages
#     101                 #delta = returns[0] - self.memory.values[i]
# --> 102             delta = rewards[i] + self.gamma*next_value*(1-self.memory.dones[i]) - values[i]
#     103             gae = delta + self.gamma*self.lambd*(1-self.memory.dones[i])*gae
#     104             #returns.insert(0,gae + self.memory.values[i])
#
# KeyboardInterrupt:
